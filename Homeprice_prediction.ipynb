# %% [markdown]
# <a href="https://colab.research.google.com/github/PushpalathaSangu/ML_Models/blob/main/Homeprice_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color='red',marker='*')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(pd.DataFrame([[3300]], columns=['area']))
# Out:
# array([628715.75342466])

# %%
#y=mx+b
#price=m*area+b
m=reg.coef_  #m
m
# Out:
# array([135.78767123])

# %%
b=reg.intercept_ #b
b
# Out:
# np.float64(180616.43835616432)

# %%
x=3300
y=m*x+b
y # predicted price for area=3300
# Out:
# array([628715.75342466])

# %%
reg.predict(pd.DataFrame([[5000]], columns=['area']))
# Out:
# array([859554.79452055])

# %%
plt.xlabel('area',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
d=pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d.head(5)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("prediction.csv")

# %%
d.to_csv("prediction.csv",index=False)

# %%
import pickle

# %%
with open ('model_pickle','wb') as f:
  pickle.dump(reg,f)

# %%
with open ('model_pickle','rb') as f:
  mp=pickle.load(f)

# %%
mp.predict(pd.DataFrame([[5000]], columns=['area']))
# Out:
# array([859554.79452055])

# %%
pip install joblib
